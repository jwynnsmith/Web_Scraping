# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
from splinter import Browser
import requests
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %% [markdown]
# # NASA Mars News

# %%
url = "https://mars.nasa.gov/news/"

# %%
response = requests.get(url)

# %%
soup = bs(response.text, 'html.parser')

# %%
news_title = soup.title.text
print(news_title)
# Out:
# News  – NASA’s Mars Exploration Program

# %%
news_p = soup.find_all('p')
for paragraph in news_p:
    print(paragraph.text)
# Out:
# Managed by the Mars Exploration Program and the Jet Propulsion Laboratory for NASA’s Science Mission Directorate

# %% [markdown]
# # JPL Mars Space Images - Featured Image

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
# Initialize browser
browser = Browser("chrome", headless=True)

# %%
full_url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"

full_image = "https://www.jpl.nasa.gov/spaceimages/details.php?id=PIA16726"

more_info_url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"

# %%
response = requests.get(url2)

# %%
soup = bs(response.text, "html.parser")

# %%
#full_image = 


featured_image_url = soup.select_one("figure.lede img").get("src") 
#featured_image_url = soup.find('https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA16715_hires.jpg')

#for image in images:
print(featured_image_url)
# Out:
# /spaceimages/images/largesize/PIA16726_hires.jpg

# %% [markdown]
# # Mars Weather

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_user = "MarsWxReport"

# %%
public_tweets = api.user_timeline(target_user)

# %%
for tweet in public_tweets:

    # Utilize JSON dumps to generate a pretty-printed json
    print(json.dumps(tweet, sort_keys=True, indent=4))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Aug 23 00:17:04 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorite_count": 22,
#     "favorited": false,
#     "geo": null,
#     "id": 1032421425779560450,
#     "id_str": "1032421425779560450",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 11,
#     "retweeted": false,
#     "source": "<a href=\"http://utprosim.com\" rel=\"nofollow\">Daily Weather Report</a>",
#     "text": "Sol 2147 (2018-08-21), high -15C/5F, low -68C/-90F, pressure at 8.70 hPa, daylight 05:30-17:44",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
# ...

# %%
print(f"Tweet Count (In Sample): {len(public_tweets)}")
# Out:
# Tweet Count (In Sample): 20

# %%
mars_weather = public_tweets[0]["text"]
print(f"Most Recent Tweet: {mars_weather}")
# Out:
# Most Recent Tweet: Sol 2147 (2018-08-21), high -15C/5F, low -68C/-90F, pressure at 8.70 hPa, daylight 05:30-17:44

# %% [markdown]
# # Mars Facts

# %%
fact_url = "http://space-facts.com/mars/"

# %%
tables = pd.read_html(fact_url)
tables
# Out:
# [                      0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.42 x 10^23 kg (10.7% Earth)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.52 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                  -153 to 20 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
df = tables[0]
df.columns = ['Parameters', 'Values']
df.head()
# Out:
#              Parameters                         Values
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.42 x 10^23 kg (10.7% Earth)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.52 AU)

# %% [markdown]
# # Mars Hemispheres
